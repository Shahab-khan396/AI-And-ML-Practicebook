# %%
age="34"
print(int(age))
# Out:
# 34

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
print(int(age))
# Out:
# 34

# %%
int(age)
print(type(age))
# Out:
# <class 'str'>

# %%
print(int(age)+1)
# Out:
# 35

# %%
print(type(age))
# Out:
# <class 'str'>
